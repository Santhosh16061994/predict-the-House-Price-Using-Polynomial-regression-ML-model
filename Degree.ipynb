# %%
a = np.arange(1,6)
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
b = a

# %%
b
# Out:
# array([1, 2, 3, 4, 5])

# %%
b
# Out:
# array([1, 2, 3, 4, 5])

# %%
plt.plot(a,b)

# %%
plt.plot(a,b**2)

# %%
plt.plot(a,b**3)

# %%
plt.plot(a,b**4)

# %%
plt.plot(a,b**5)
